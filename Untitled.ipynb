# %%
pip install hvplot
# Out:
# ...
#
# ...

# %%
pip install plotly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge firefox geckodriver
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\maite\anaconda3
#
#   added / updated specs:
#     - firefox
#     - geckodriver
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     firefox-101.0              |       h0e60522_0        70.8 MB  conda-forge
#     geckodriver-0.30.0         |       hdb13177_0         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        72.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   firefox            conda-forge/win-64::firefox-101.0-h0e60522_0
#   geckodriver        conda-forge/win-64::geckodriver-0.30.0-hdb13177_0
#
#
#
# ...
#
# firefox-101.0        | 70.8 MB   |            |   0%
# firefox-101.0        | 70.8 MB   |            |   0%
# firefox-101.0        | 70.8 MB   |            |   0%
# ...
